# %%
import pandas as pd

# %%
# 데이터 읽어오기
df = pd.read_csv('./train_mdf.csv',header=None)

# %%
df
# Out:
#         0           1         2            3        4       5      6   \
# 0       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1        1          60        RL           65     8450    Pave    NaN
# 2        2          20        RL           80     9600    Pave    NaN
# 3        3          60        RL           68    11250    Pave    NaN
# 4        4          70        RL           60     9550    Pave    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1456  1456          60        RL           62     7917    Pave    NaN
# 1457  1457          20        RL           85    13175    Pave    NaN
# 1458  1458          70        RL           66     9042    Pave    NaN
# 1459  1459          20        RL           68     9717    Pave    NaN
# 1460  1460          20        RL           75     9937    Pave    NaN
#
#             7            8          9   ...        71      72     73  \
# ...

# %%
# 컬럼명 리스트업
columns_name = df.iloc[0]
type(columns_name)
columns_name
# Out:
# 0                Id
# 1        MSSubClass
# 2          MSZoning
# 3       LotFrontage
# 4           LotArea
#           ...
# 76           MoSold
# 77           YrSold
# 78         SaleType
# 79    SaleCondition
# 80        SalePrice
# Name: 0, Length: 81, dtype: object

# %%
# 데이터 정보확인
df.columns = list(columns_name)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1461 non-null   object
#  1   MSSubClass     1461 non-null   object
#  2   MSZoning       1461 non-null   object
#  3   LotFrontage    1202 non-null   object
#  4   LotArea        1461 non-null   object
#  5   Street         1461 non-null   object
#  6   Alley          92 non-null     object
#  7   LotShape       1461 non-null   object
#  8   LandContour    1461 non-null   object
#  9   Utilities      1461 non-null   object
#  10  LotConfig      1461 non-null   object
#  11  LandSlope      1461 non-null   object
#  12  Neighborhood   1461 non-null   object
#  13  Condition1     1461 non-null   object
#  14  Condition2     1461 non-null   object
#  15  BldgType       1461 non-null   object
#  16  HouseStyle     1461 non-null   object
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape
# 1   1          60        RL           65     8450    Pave    NaN       Reg
# 2   2          20        RL           80     9600    Pave    NaN       Reg
# 3   3          60        RL           68    11250    Pave    NaN       IR1
# 4   4          70        RL           60     9550    Pave    NaN       IR1
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal
# 1          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 2          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 3          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 4          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
#
# ...

# %%
df.tail()
# Out:
#         Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 1456  1456         60       RL          62    7917   Pave   NaN      Reg
# 1457  1457         20       RL          85   13175   Pave   NaN      Reg
# 1458  1458         70       RL          66    9042   Pave   NaN      Reg
# 1459  1459         20       RL          68    9717   Pave   NaN      Reg
# 1460  1460         20       RL          75    9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1458         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1460         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold SaleType SaleCondition SalePrice
# ...
